# %% [markdown]
# # Test reading and manipulating csv file

# %% [markdown]
# ### Import libraries :

# %%
import pandas as pd
import os
os.chdir("/Users/stephanesingery/Downloads")

# %% [markdown]
# ### Create the csv file path and read the file (5 first lines) :

# %%
file_path = "/Users/stephanesingery/Downloads/DataAnalyst.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %% [markdown]
# ### Create a data frame from csv_file consisting on 4 main column (5 first lines) :

# %%
y = df[["Job Title","Salary Estimate", "Rating", "Size"]]
y.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  Rating                    Size
# 0  $37K-$66K (Glassdoor est.)     3.2    201 to 500 employees
# 1  $37K-$66K (Glassdoor est.)     3.8        10000+ employees
# 2  $37K-$66K (Glassdoor est.)     3.4  1001 to 5000 employees
# 3  $37K-$66K (Glassdoor est.)     4.1    201 to 500 employees
# 4  $37K-$66K (Glassdoor est.)     3.9   501 to 1000 employees

# %% [markdown]
# ### LOC : Create a data frame from csv file, from line 15 to line 24, from column "Job Title" to column "Type of ownership" :

# %%
z = df.loc[15:24, 'Job Title': "Type of ownership"]
z
# Out:
#                          Job Title             Salary Estimate  \
# 15     Sustainability Data Analyst  $37K-$66K (Glassdoor est.)
# 16                    Data Analyst  $37K-$66K (Glassdoor est.)
# 17           Clinical Data Analyst  $37K-$66K (Glassdoor est.)
# 18         DATA PROGRAMMER/ANALYST  $37K-$66K (Glassdoor est.)
# 19                    Data Analyst  $37K-$66K (Glassdoor est.)
# 20   Product Analyst, Data Science  $37K-$66K (Glassdoor est.)
# 21            Data Science Analyst  $37K-$66K (Glassdoor est.)
# 22  Data Analyst - Intex Developer  $37K-$66K (Glassdoor est.)
# 23                    Data Analyst  $37K-$66K (Glassdoor est.)
# 24  Entry Level / Jr. Data Analyst  $37K-$66K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 15  Job Description\nRole Description\n\nSustainab...     3.6
# 16  Undertone stands alone among AdTech and ad net...     3.8
# 17  About Us:\n\nNYSTEC is a non-profit technology...     3.8
# ...

# %% [markdown]
# ### ILOC : Create a data frame from csv file, from line 15 to line 24, from column 0 to column 6 :

# %%
g = df.iloc[15:24, 0:7]
g
# Out:
#     Unnamed: 0                       Job Title             Salary Estimate  \
# 15          15     Sustainability Data Analyst  $37K-$66K (Glassdoor est.)
# 16          16                    Data Analyst  $37K-$66K (Glassdoor est.)
# 17          17           Clinical Data Analyst  $37K-$66K (Glassdoor est.)
# 18          18         DATA PROGRAMMER/ANALYST  $37K-$66K (Glassdoor est.)
# 19          19                    Data Analyst  $37K-$66K (Glassdoor est.)
# 20          20   Product Analyst, Data Science  $37K-$66K (Glassdoor est.)
# 21          21            Data Science Analyst  $37K-$66K (Glassdoor est.)
# 22          22  Data Analyst - Intex Developer  $37K-$66K (Glassdoor est.)
# 23          23                    Data Analyst  $37K-$66K (Glassdoor est.)
#
#                                       Job Description  Rating  \
# 15  Job Description\nRole Description\n\nSustainab...     3.6
# 16  Undertone stands alone among AdTech and ad net...     3.8
# ...

# %% [markdown]
# ### Values list of "Industry" column from line 0 to line 19 of the result :

# %%
x = df['Industry'].unique()
x[0:20]
# Out:
# array(['Social Assistance', 'Health Care Services & Hospitals',
#        'Internet', 'IT Services', 'Sports & Recreation',
#        'Investment Banking & Asset Management', 'Insurance Carriers',
#        'Venture Capital & Private Equity', 'Research & Development', '-1',
#        'Advertising & Marketing', 'Brokerage Services',
#        'Building & Personnel Services', 'Consulting',
#        'Casual Restaurants', 'Enterprise Software & Network Solutions',
#        'Lending', 'Banks & Credit Unions', 'Computer Hardware & Software',
#        'Staffing & Outsourcing'], dtype=object)

# %% [markdown]
# ### Create a data frame from csv file with only "industry" corresponding to "IT Services" (5 first lines) :

# %%
df1 = df[df["Industry"] == "IT Services"]
del df1['Job Description']
df1.head()
# Out:
#     Unnamed: 0                                       Job Title  \
# 3            3                                    Data Analyst
# 49          49                    Senior Analyst, Data Science
# 52          52                           Business Data Analyst
# 61          61  Data Analyst - Data Acquisition / Data Lineage
# 62          62  Data Analyst - Data Scanning utilizing Rochade
#
#                Salary Estimate  Rating              Company Name  \
# 3   $37K-$66K (Glassdoor est.)     4.1             Celerity\n4.1
# 49  $46K-$87K (Glassdoor est.)     3.9                 Roku\n3.9
# 52  $46K-$87K (Glassdoor est.)     3.7  Xoriant Corporation\n3.7
# 61  $51K-$88K (Glassdoor est.)     3.6           Perficient\n3.6
# 62  $51K-$88K (Glassdoor est.)     3.6           Perficient\n3.6
#
#            Location     Headquarters                    Size  Founded  \
# 3      New York, NY       McLean, VA    201 to 500 employees     2002
# ...

# %% [markdown]
# ### Create a new csv file corresponding to the last data frame :

# %%
df1.to_csv("test_DA_job_indusry.csv")
